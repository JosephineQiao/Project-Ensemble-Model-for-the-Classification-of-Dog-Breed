# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/120dog breeds-224.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/projectDataset224')

# %%
import pandas as pd
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras import applications
from keras.layers import Activation, Dropout, Flatten, Dense,GlobalAveragePooling2D, BatchNormalization

# %%
import pathlib
from keras.preprocessing.image import ImageDataGenerator


data_dir = pathlib.Path('/content/projectDataset224/120dog breeds-224')

data_train = data_dir / 'train'

test_dir = data_dir / 'test'


labels_csv = pd.read_csv('/content/drive/MyDrive/labels.csv')
labels_csv['id'] = [str(fname) + '.jpg' for fname in labels_csv['id']]

# %%
batch_size = 16
img_size = 224

# %%
# datagen = ImageDataGenerator(preprocessing_function = keras.applications.resnet50.preprocess_input, validation_split=0.2)
# train_generator = datagen.flow_from_dataframe(
#                         dataframe = labels_csv,
#                         directory = data_train,
#                         subset='training',
#                         x_col='id',
#                         y_col='breed',
#                         batch_size=batch_size,
#                         shuffle=True,
#                         class_mode='sparse',
#                         color_mode='rgb',
#                         target_size=(img_size, img_size))

# validation_generator = datagen.flow_from_dataframe(
#                         dataframe = labels_csv,
#                         directory = data_train,
#                         subset='validation',
#                         x_col='id', 
#                         y_col='breed',
#                         batch_size=batch_size,
#                         shuffle=True,
#                         class_mode='sparse',
#                         color_mode='rgb',
#                         target_size=(img_size, img_size))


train_datagen = ImageDataGenerator(
    preprocessing_function=keras.applications.resnet50.preprocess_input,
    validation_split=0.2,
    rotation_range=20, 
    width_shift_range=0.2, 
    height_shift_range=0.2, 
    zoom_range=0.2, 
    horizontal_flip=True, 
    vertical_flip=True
)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=labels_csv,
    directory=data_train,
    subset='training',
    x_col='id',
    y_col='breed',
    batch_size=batch_size,
    shuffle=True,
    class_mode='sparse',
    color_mode='rgb',
    target_size=(img_size, img_size)
)

validation_datagen = ImageDataGenerator(
    preprocessing_function = keras.applications.resnet50.preprocess_input, 
    validation_split=0.2
)

validation_generator = validation_datagen.flow_from_dataframe(
    dataframe=labels_csv,
    directory=data_train,
    subset='validation',
    x_col='id',
    y_col='breed',
    batch_size=batch_size,
    shuffle=True,
    class_mode='sparse',
    color_mode='rgb',
    target_size=(img_size, img_size)
)
# Out:
# Found 8178 validated image filenames belonging to 120 classes.
# Found 2044 validated image filenames belonging to 120 classes.

# %%
resnet50 = keras.applications.ResNet50(include_top=False, weights='imagenet',input_shape=(224,224,3))

for layer in resnet50.layers:
    layer.trainable=False

model = Sequential()
model.add(resnet50)
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.5))
model.add(Dense(2048, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(120, activation='softmax'))
model.summary()

optimizer=tf.keras.optimizers.Adam(learning_rate = 0.0001)
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              #loss='categorical_crossentropy',
              #loss='SparseSoftmaxCrossEntropyWithLogits',
              #loss='SparseSoftmaxCrossEntropyWithLogits',
              metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  batch_normalization (BatchN  (None, 7, 7, 2048)       8192
#  ormalization)
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 2048)              4196352
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_1 (Dense)             (None, 120)               245880
#
# =================================================================
# Total params: 28,038,136
# Trainable params: 4,446,328
# Non-trainable params: 23,591,808
# _________________________________________________________________

# %%
history_res = model.fit(train_generator, epochs=20, verbose = 1,
                       validation_data=validation_generator)

# from keras.callbacks import ModelCheckpoint, EarlyStopping


# checkpoint_cb = ModelCheckpoint("/content/drive/MyDrive/Resnet50Newversion1.h5", save_best_only=True)
# early_stopping_cb = EarlyStopping(patience=5, restore_best_weights=True)


# history_res = model.fit(train_generator, epochs=50, verbose = 1,
#                         validation_data=validation_generator,
#                         callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/20
# 512/512 [==============================] - 136s 238ms/step - loss: 4.2159 - accuracy: 0.1195 - val_loss: 2.7130 - val_accuracy: 0.4990
# Epoch 2/20
# 512/512 [==============================] - 121s 237ms/step - loss: 2.9780 - accuracy: 0.3319 - val_loss: 1.5994 - val_accuracy: 0.6365
# Epoch 3/20
# 512/512 [==============================] - 119s 231ms/step - loss: 2.3670 - accuracy: 0.4282 - val_loss: 1.1865 - val_accuracy: 0.6884
# Epoch 4/20
# 512/512 [==============================] - 118s 231ms/step - loss: 2.0628 - accuracy: 0.4744 - val_loss: 1.0162 - val_accuracy: 0.7192
# Epoch 5/20
# 512/512 [==============================] - 117s 228ms/step - loss: 1.8760 - accuracy: 0.5094 - val_loss: 0.9329 - val_accuracy: 0.7226
# Epoch 6/20
# 512/512 [==============================] - 120s 234ms/step - loss: 1.7752 - accuracy: 0.5246 - val_loss: 0.8781 - val_accuracy: 0.7348
# Epoch 7/20
# 512/512 [==============================] - 120s 234ms/step - loss: 1.6826 - accuracy: 0.5396 - val_loss: 0.8535 - val_accuracy: 0.7353
# Epoch 8/20
# 512/512 [==============================] - 124s 241ms/step - loss: 1.6150 - accuracy: 0.5556 - val_loss: 0.8277 - val_accuracy: 0.7441
# Epoch 9/20
# 512/512 [==============================] - 121s 236ms/step - loss: 1.5798 - accuracy: 0.5715 - val_loss: 0.8240 - val_accuracy: 0.7476
# Epoch 10/20
# 512/512 [==============================] - 121s 236ms/step - loss: 1.5542 - accuracy: 0.5751 - val_loss: 0.8019 - val_accuracy: 0.7534
# Epoch 11/20
# 512/512 [==============================] - 121s 236ms/step - loss: 1.4829 - accuracy: 0.5814 - val_loss: 0.7969 - val_accuracy: 0.7529
# Epoch 12/20
# 512/512 [==============================] - 122s 238ms/step - loss: 1.4538 - accuracy: 0.5944 - val_loss: 0.7912 - val_accuracy: 0.7495
# Epoch 13/20
# 512/512 [==============================] - 127s 247ms/step - loss: 1.4282 - accuracy: 0.5965 - val_loss: 0.7863 - val_accuracy: 0.7573
# Epoch 14/20
# 512/512 [==============================] - 123s 241ms/step - loss: 1.3923 - accuracy: 0.6119 - val_loss: 0.7914 - val_accuracy: 0.7466
# Epoch 15/20
# 512/512 [==============================] - 123s 241ms/step - loss: 1.3550 - accuracy: 0.6140 - val_loss: 0.7830 - val_accuracy: 0.7510
# Epoch 16/20
# 512/512 [==============================] - 125s 244ms/step - loss: 1.3470 - accuracy: 0.6179 - val_loss: 0.7822 - val_accuracy: 0.7524
# Epoch 17/20
# 512/512 [==============================] - 126s 246ms/step - loss: 1.2923 - accuracy: 0.6343 - val_loss: 0.7743 - val_accuracy: 0.7613
# Epoch 18/20
# 512/512 [==============================] - 123s 239ms/step - loss: 1.2931 - accuracy: 0.6301 - val_loss: 0.7803 - val_accuracy: 0.7613
# Epoch 19/20
# 512/512 [==============================] - 123s 240ms/step - loss: 1.2684 - accuracy: 0.6406 - val_loss: 0.7859 - val_accuracy: 0.7549
# Epoch 20/20
# 512/512 [==============================] - 126s 245ms/step - loss: 1.2588 - accuracy: 0.6436 - val_loss: 0.7738 - val_accuracy: 0.7598

# %%
model.save('/content/drive/MyDrive/Resnet50NewVersion1-new')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.

# %%
plt.figure()
plt.plot(history_res .history['val_loss'], label = 'Val loss')
plt.plot(history_res .history['loss'], label = 'Train loss')
plt.legend()
plt.show()
plt.figure()
plt.plot(history_res .history['val_accuracy'], label = 'Val accuracy')
plt.plot(history_res .history['accuracy'], label = 'Accuracy')
plt.legend()
plt.show()
