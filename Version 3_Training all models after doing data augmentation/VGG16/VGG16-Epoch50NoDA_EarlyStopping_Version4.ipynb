# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/120dog breeds-224.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/projectDataset224')

# %%
import pandas as pd
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras import applications
from keras.layers import Activation, Dropout, Flatten, Dense, GlobalAveragePooling2D, BatchNormalization
from keras.callbacks import ModelCheckpoint

# %%
import pathlib
from keras.preprocessing.image import ImageDataGenerator


data_dir = pathlib.Path('/content/projectDataset224/120dog breeds-224')

data_train = data_dir / 'train'

test_dir = data_dir / 'test'


labels_csv = pd.read_csv('/content/drive/MyDrive/labels.csv')
labels_csv['id'] = [str(fname) + '.jpg' for fname in labels_csv['id']]

# %%
batch_size = 16
img_size = 224

# %%
datagen = ImageDataGenerator(preprocessing_function = keras.applications.vgg16.preprocess_input, validation_split=0.2)

train_generator = datagen.flow_from_dataframe(
                        dataframe = labels_csv,
                        directory = data_train,
                        subset="training",
                        x_col="id",
                        y_col="breed",
                        batch_size=batch_size,
                        shuffle=True,
                        # class_mode="sparse",
                        class_mode='categorical',
                        color_mode="rgb",
                        target_size=(img_size, img_size))

validation_generator = datagen.flow_from_dataframe(
                        dataframe = labels_csv,
                        directory = data_train,
                        subset="validation",
                        x_col="id",
                        y_col="breed",
                        batch_size=batch_size,
                        shuffle=True,
                        # class_mode="sparse",
                        class_mode='categorical',
                        color_mode="rgb",
                        target_size=(img_size, img_size))

# 
# train_datagen = ImageDataGenerator(
#     preprocessing_function=keras.applications.vgg16.preprocess_input,
#     validation_split=0.2,
#     rotation_range=5,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     zoom_range=0.1,
#     shear_range=0.05,
#     brightness_range=[0.8, 1.2],
#     horizontal_flip=True
# )


# train_generator = train_datagen.flow_from_dataframe(
#     dataframe=labels_csv,
#     directory=data_train,
#     subset='training',
#     x_col='id',
#     y_col='breed',
#     batch_size=batch_size,
#     shuffle=True,
#     # class_mode='sparse',
#     class_mode='categorical',
#     color_mode='rgb',
#     target_size=(img_size, img_size)
# )

# validation_datagen = ImageDataGenerator(
#     preprocessing_function = keras.applications.vgg16.preprocess_input, 
#     validation_split=0.2
# )

# validation_generator = validation_datagen.flow_from_dataframe(
#     dataframe=labels_csv,
#     directory=data_train,
#     subset='validation',
#     x_col='id',
#     y_col='breed',
#     batch_size=batch_size,
#     shuffle=True,
#     # class_mode='sparse',
#     class_mode='categorical',
#     color_mode='rgb',
#     target_size=(img_size, img_size)
# )


from keras.utils import to_categorical
train_labels = to_categorical(train_generator.labels)
validation_labels = to_categorical(validation_generator.labels)
# Out:
# Found 8178 validated image filenames belonging to 120 classes.
# Found 2044 validated image filenames belonging to 120 classes.

# %%
import tensorflow as tf
from tensorflow.python.keras.metrics import AUC
from sklearn.metrics import roc_curve, auc

# Define the ROC metrics
tpr = tf.keras.metrics.TruePositives(name='tp')
fpr = tf.keras.metrics.FalsePositives(name='fp')
auc_metric = AUC(name='auc')

# %%
vgg16 = applications.vgg16.VGG16(include_top=False, weights='imagenet',input_shape=(224,224,3))

for layer in vgg16.layers:
    layer.trainable=False

model = Sequential()
model.add(vgg16)
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.5))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(120, activation='softmax'))
model.summary()

optimizer=tf.keras.optimizers.Adam(learning_rate = 0.001)
# optimizer = tf.keras.optimizers.RMSprop(learning_rate=1e-4, rho=0.9)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              # loss='sparse_categorical_crossentropy',
              # metrics=['accuracy'])
              metrics=[tpr, fpr, auc_metric, 'accuracy', 'Precision', 'Recall'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  batch_normalization_1 (Batc  (None, 7, 7, 512)        2048
#  hNormalization)
#
#  global_average_pooling2d_1   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 1024)              525312
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 256)               262400
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 120)               30840
#
# =================================================================
# Total params: 15,535,288
# Trainable params: 819,576
# Non-trainable params: 14,715,712
# _________________________________________________________________

# %%
# history_vgg = model.fit(train_generator, epochs=50, verbose = 1,
#                         validation_data=validation_generator)

from keras.callbacks import ModelCheckpoint, EarlyStopping


checkpoint_cb = ModelCheckpoint("/content/drive/MyDrive/VGG16-Epoch50DataAugmentationHighROCVersion.h5", save_best_only=True)
early_stopping_cb = EarlyStopping(patience=5, restore_best_weights=True)


history_vgg = model.fit(train_generator, epochs=50, verbose = 1,
                        validation_data=validation_generator,
                        callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/50
# 512/512 [==============================] - 62s 96ms/step - loss: 3.9342 - tp: 133.0000 - fp: 156.0000 - auc: 0.6814 - accuracy: 0.1149 - precision: 0.4602 - recall: 0.0163 - val_loss: 2.1580 - val_tp: 226.0000 - val_fp: 46.0000 - val_auc: 0.8229 - val_accuracy: 0.4584 - val_precision: 0.8309 - val_recall: 0.1106
# Epoch 2/50
# 512/512 [==============================] - 46s 90ms/step - loss: 2.7617 - tp: 969.0000 - fp: 838.0000 - auc: 0.8660 - accuracy: 0.2816 - precision: 0.5362 - recall: 0.1185 - val_loss: 1.6882 - val_tp: 534.0000 - val_fp: 124.0000 - val_auc: 0.8900 - val_accuracy: 0.5431 - val_precision: 0.8116 - val_recall: 0.2613
# Epoch 3/50
# 512/512 [==============================] - 48s 93ms/step - loss: 2.4399 - tp: 1406.0000 - fp: 1031.0000 - auc: 0.9038 - accuracy: 0.3440 - precision: 0.5769 - recall: 0.1719 - val_loss: 1.5061 - val_tp: 677.0000 - val_fp: 152.0000 - val_auc: 0.9132 - val_accuracy: 0.5851 - val_precision: 0.8166 - val_recall: 0.3312
# Epoch 4/50
# 512/512 [==============================] - 46s 91ms/step - loss: 2.2648 - tp: 1784.0000 - fp: 1187.0000 - auc: 0.9202 - accuracy: 0.3815 - precision: 0.6005 - recall: 0.2181 - val_loss: 1.4125 - val_tp: 749.0000 - val_fp: 155.0000 - val_auc: 0.9255 - val_accuracy: 0.6169 - val_precision: 0.8285 - val_recall: 0.3664
# Epoch 5/50
# 512/512 [==============================] - 47s 91ms/step - loss: 2.1239 - tp: 2057.0000 - fp: 1210.0000 - auc: 0.9299 - accuracy: 0.4085 - precision: 0.6296 - recall: 0.2515 - val_loss: 1.3525 - val_tp: 815.0000 - val_fp: 197.0000 - val_auc: 0.9335 - val_accuracy: 0.6052 - val_precision: 0.8053 - val_recall: 0.3987
# Epoch 6/50
# 512/512 [==============================] - 47s 91ms/step - loss: 2.0503 - tp: 2253.0000 - fp: 1197.0000 - auc: 0.9364 - accuracy: 0.4323 - precision: 0.6530 - recall: 0.2755 - val_loss: 1.3135 - val_tp: 839.0000 - val_fp: 172.0000 - val_auc: 0.9387 - val_accuracy: 0.6331 - val_precision: 0.8299 - val_recall: 0.4105
# Epoch 7/50
# 512/512 [==============================] - 47s 92ms/step - loss: 1.9761 - tp: 2351.0000 - fp: 1218.0000 - auc: 0.9409 - accuracy: 0.4526 - precision: 0.6587 - recall: 0.2875 - val_loss: 1.2889 - val_tp: 877.0000 - val_fp: 181.0000 - val_auc: 0.9428 - val_accuracy: 0.6336 - val_precision: 0.8289 - val_recall: 0.4291
# Epoch 8/50
# 512/512 [==============================] - 46s 89ms/step - loss: 1.9596 - tp: 2461.0000 - fp: 1279.0000 - auc: 0.9444 - accuracy: 0.4609 - precision: 0.6580 - recall: 0.3009 - val_loss: 1.3002 - val_tp: 852.0000 - val_fp: 181.0000 - val_auc: 0.9458 - val_accuracy: 0.6341 - val_precision: 0.8248 - val_recall: 0.4168
# Epoch 9/50
# 512/512 [==============================] - 46s 91ms/step - loss: 1.8938 - tp: 2567.0000 - fp: 1254.0000 - auc: 0.9472 - accuracy: 0.4784 - precision: 0.6718 - recall: 0.3139 - val_loss: 1.2678 - val_tp: 906.0000 - val_fp: 200.0000 - val_auc: 0.9483 - val_accuracy: 0.6316 - val_precision: 0.8192 - val_recall: 0.4432
# Epoch 10/50
# 512/512 [==============================] - 47s 91ms/step - loss: 1.8766 - tp: 2665.0000 - fp: 1257.0000 - auc: 0.9493 - accuracy: 0.4803 - precision: 0.6795 - recall: 0.3259 - val_loss: 1.2490 - val_tp: 925.0000 - val_fp: 165.0000 - val_auc: 0.9502 - val_accuracy: 0.6458 - val_precision: 0.8486 - val_recall: 0.4525
# Epoch 11/50
# 512/512 [==============================] - 46s 89ms/step - loss: 1.8642 - tp: 2648.0000 - fp: 1275.0000 - auc: 0.9512 - accuracy: 0.4775 - precision: 0.6750 - recall: 0.3238 - val_loss: 1.2721 - val_tp: 894.0000 - val_fp: 198.0000 - val_auc: 0.9519 - val_accuracy: 0.6326 - val_precision: 0.8187 - val_recall: 0.4374
# Epoch 12/50
# 512/512 [==============================] - 47s 91ms/step - loss: 1.8322 - tp: 2707.0000 - fp: 1272.0000 - auc: 0.9527 - accuracy: 0.4880 - precision: 0.6803 - recall: 0.3310 - val_loss: 1.2247 - val_tp: 938.0000 - val_fp: 188.0000 - val_auc: 0.9533 - val_accuracy: 0.6517 - val_precision: 0.8330 - val_recall: 0.4589
# Epoch 13/50
# 512/512 [==============================] - 46s 89ms/step - loss: 1.8031 - tp: 2780.0000 - fp: 1373.0000 - auc: 0.9539 - accuracy: 0.4891 - precision: 0.6694 - recall: 0.3399 - val_loss: 1.2499 - val_tp: 912.0000 - val_fp: 222.0000 - val_auc: 0.9545 - val_accuracy: 0.6365 - val_precision: 0.8042 - val_recall: 0.4462
# Epoch 14/50
# 512/512 [==============================] - 48s 94ms/step - loss: 1.7807 - tp: 2818.0000 - fp: 1348.0000 - auc: 0.9550 - accuracy: 0.4960 - precision: 0.6764 - recall: 0.3446 - val_loss: 1.2124 - val_tp: 934.0000 - val_fp: 186.0000 - val_auc: 0.9555 - val_accuracy: 0.6380 - val_precision: 0.8339 - val_recall: 0.4569
# Epoch 15/50
# 512/512 [==============================] - 46s 89ms/step - loss: 1.7811 - tp: 2929.0000 - fp: 1322.0000 - auc: 0.9560 - accuracy: 0.5015 - precision: 0.6890 - recall: 0.3582 - val_loss: 1.2238 - val_tp: 911.0000 - val_fp: 172.0000 - val_auc: 0.9564 - val_accuracy: 0.6517 - val_precision: 0.8412 - val_recall: 0.4457
# Epoch 16/50
# 512/512 [==============================] - 48s 95ms/step - loss: 1.7353 - tp: 2954.0000 - fp: 1315.0000 - auc: 0.9569 - accuracy: 0.5136 - precision: 0.6920 - recall: 0.3612 - val_loss: 1.1925 - val_tp: 953.0000 - val_fp: 187.0000 - val_auc: 0.9573 - val_accuracy: 0.6629 - val_precision: 0.8360 - val_recall: 0.4662
# Epoch 17/50
# 512/512 [==============================] - 46s 89ms/step - loss: 1.7364 - tp: 2986.0000 - fp: 1306.0000 - auc: 0.9577 - accuracy: 0.5138 - precision: 0.6957 - recall: 0.3651 - val_loss: 1.2474 - val_tp: 942.0000 - val_fp: 173.0000 - val_auc: 0.9580 - val_accuracy: 0.6477 - val_precision: 0.8448 - val_recall: 0.4609
# Epoch 18/50
# 512/512 [==============================] - 46s 89ms/step - loss: 1.7342 - tp: 3006.0000 - fp: 1328.0000 - auc: 0.9584 - accuracy: 0.5106 - precision: 0.6936 - recall: 0.3676 - val_loss: 1.2130 - val_tp: 999.0000 - val_fp: 201.0000 - val_auc: 0.9586 - val_accuracy: 0.6585 - val_precision: 0.8325 - val_recall: 0.4887
# Epoch 19/50
# 512/512 [==============================] - 46s 89ms/step - loss: 1.7212 - tp: 3089.0000 - fp: 1378.0000 - auc: 0.9590 - accuracy: 0.5112 - precision: 0.6915 - recall: 0.3777 - val_loss: 1.2158 - val_tp: 969.0000 - val_fp: 191.0000 - val_auc: 0.9593 - val_accuracy: 0.6561 - val_precision: 0.8353 - val_recall: 0.4741
# Epoch 20/50
# 512/512 [==============================] - 47s 91ms/step - loss: 1.7048 - tp: 3169.0000 - fp: 1345.0000 - auc: 0.9596 - accuracy: 0.5301 - precision: 0.7020 - recall: 0.3875 - val_loss: 1.2230 - val_tp: 979.0000 - val_fp: 188.0000 - val_auc: 0.9598 - val_accuracy: 0.6512 - val_precision: 0.8389 - val_recall: 0.4790
# Epoch 21/50
# 512/512 [==============================] - 45s 88ms/step - loss: 1.7146 - tp: 3109.0000 - fp: 1407.0000 - auc: 0.9600 - accuracy: 0.5245 - precision: 0.6884 - recall: 0.3802 - val_loss: 1.2160 - val_tp: 988.0000 - val_fp: 206.0000 - val_auc: 0.9602 - val_accuracy: 0.6522 - val_precision: 0.8275 - val_recall: 0.4834

# %%
model.save('/content/drive/MyDrive/VGG16-Epoch50ROCVersion4.h5')

# %%
plt.figure()
plt.plot(history_vgg .history['val_loss'], label = 'Val loss')
plt.plot(history_vgg .history['loss'], label = 'Train loss')
plt.legend()
plt.show()
plt.figure()
plt.plot(history_vgg .history['val_accuracy'], label = 'Val accuracy')
plt.plot(history_vgg .history['accuracy'], label = 'Accuracy')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(history_vgg .history['val_auc'], label = 'val_auc')
plt.plot(history_vgg .history['auc'], label = 'Train auc')
plt.legend()
plt.show()

plt.figure()
plt.plot(history_vgg .history['val_tp'], label = 'Val TP')
plt.plot(history_vgg .history['tp'], label = 'Train TP')
plt.plot(history_vgg .history['val_fp'], label = 'Val FP')
plt.plot(history_vgg .history['fp'], label = 'Train FP')
plt.legend()
plt.show()

plt.figure()
plt.plot(history_vgg .history['val_precision'], label = 'Val Precision')
plt.plot(history_vgg .history['precision'], label = 'Train Precision')
plt.legend()
plt.show()

plt.figure()
plt.plot(history_vgg .history['val_recall'], label = 'Val Recall')
plt.plot(history_vgg .history['recall'], label = 'Train Recall')
plt.legend()
plt.show()
