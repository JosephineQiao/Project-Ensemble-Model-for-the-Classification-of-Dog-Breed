# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/120dog breeds-224.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/projectDataset224')

# %%
import pandas as pd
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras import applications
from keras.layers import Activation, Dropout, Flatten, Dense, GlobalAveragePooling2D, BatchNormalization
from keras.callbacks import ModelCheckpoint

# %%
import pathlib
from keras.preprocessing.image import ImageDataGenerator


data_dir = pathlib.Path('/content/projectDataset224/120dog breeds-224')

data_train = data_dir / 'train'

test_dir = data_dir / 'test'


labels_csv = pd.read_csv('/content/drive/MyDrive/labels.csv')
labels_csv['id'] = [str(fname) + '.jpg' for fname in labels_csv['id']]

# %%
batch_size = 16
img_size = 224

# %%
# datagen = ImageDataGenerator(preprocessing_function = keras.applications.vgg16.preprocess_input, validation_split=0.2)

# train_generator = datagen.flow_from_dataframe(
#                         dataframe = labels_csv,
#                         directory = data_train,
#                         subset="training",
#                         x_col="id",
#                         y_col="breed",
#                         batch_size=batch_size,
#                         shuffle=True,
#                         class_mode="sparse",
#                         color_mode="rgb",
#                         target_size=(img_size, img_size))

# validation_generator = datagen.flow_from_dataframe(
#                         dataframe = labels_csv,
#                         directory = data_train,
#                         subset="validation",
#                         x_col="id",
#                         y_col="breed",
#                         batch_size=batch_size,
#                         shuffle=True,
#                         class_mode="sparse",
#                         color_mode="rgb",
#                         target_size=(img_size, img_size))

train_datagen = ImageDataGenerator(
    preprocessing_function=keras.applications.vgg16.preprocess_input,
    validation_split=0.2,
    rotation_range=5,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    shear_range=0.05,
    brightness_range=[0.8, 1.2],
    horizontal_flip=True
)


train_generator = train_datagen.flow_from_dataframe(
    dataframe=labels_csv,
    directory=data_train,
    subset='training',
    x_col='id',
    y_col='breed',
    batch_size=batch_size,
    shuffle=True,
    # class_mode='sparse',
    class_mode='categorical',
    color_mode='rgb',
    target_size=(img_size, img_size)
)

validation_datagen = ImageDataGenerator(
    preprocessing_function = keras.applications.vgg16.preprocess_input, 
    validation_split=0.2
)

validation_generator = validation_datagen.flow_from_dataframe(
    dataframe=labels_csv,
    directory=data_train,
    subset='validation',
    x_col='id',
    y_col='breed',
    batch_size=batch_size,
    shuffle=True,
    # class_mode='sparse',
    class_mode='categorical',
    color_mode='rgb',
    target_size=(img_size, img_size)
)



from keras.utils import to_categorical
train_labels = to_categorical(train_generator.labels)
validation_labels = to_categorical(validation_generator.labels)
# Out:
# Found 8178 validated image filenames belonging to 120 classes.
# Found 2044 validated image filenames belonging to 120 classes.

# %%
import tensorflow as tf
from tensorflow.python.keras.metrics import AUC
from sklearn.metrics import roc_curve, auc

# Define the ROC metrics
tpr = tf.keras.metrics.TruePositives(name='tp')
fpr = tf.keras.metrics.FalsePositives(name='fp')
auc_metric = AUC(name='auc')

# %%
vgg16 = applications.vgg16.VGG16(include_top=False, weights='imagenet',input_shape=(224,224,3))

for layer in vgg16.layers:
    layer.trainable=False

model = Sequential()
model.add(vgg16)
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.5))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(120, activation='softmax'))
model.summary()

optimizer=tf.keras.optimizers.Adam(learning_rate = 0.001)
# optimizer = tf.keras.optimizers.RMSprop(learning_rate=1e-4, rho=0.9)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              # loss='sparse_categorical_crossentropy',
              # metrics=['accuracy'])
              metrics=[tpr, fpr, auc_metric, 'accuracy', 'Precision', 'Recall'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  batch_normalization (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 256)               262400
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 120)               30840
#
# =================================================================
# Total params: 15,535,288
# Trainable params: 819,576
# Non-trainable params: 14,715,712
# _________________________________________________________________

# %%
# history_vgg = model.fit(train_generator, epochs=50, verbose = 1,
#                         validation_data=validation_generator)

from keras.callbacks import ModelCheckpoint, EarlyStopping


checkpoint_cb = ModelCheckpoint("/content/drive/MyDrive/VGG16-Epoch50DataAugmentationHighROCVersion.h5", save_best_only=True)
early_stopping_cb = EarlyStopping(patience=5, restore_best_weights=True)


history_vgg = model.fit(train_generator, epochs=50, verbose = 1,
                        validation_data=validation_generator,
                        callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/50
# 512/512 [==============================] - 167s 289ms/step - loss: 3.9951 - tp: 120.0000 - fp: 154.0000 - auc: 0.6690 - accuracy: 0.1130 - precision: 0.4380 - recall: 0.0147 - val_loss: 2.1795 - val_tp: 252.0000 - val_fp: 75.0000 - val_auc: 0.8134 - val_accuracy: 0.4486 - val_precision: 0.7706 - val_recall: 0.1233
# Epoch 2/50
# 512/512 [==============================] - 136s 265ms/step - loss: 2.8656 - tp: 822.0000 - fp: 757.0000 - auc: 0.8582 - accuracy: 0.2693 - precision: 0.5206 - recall: 0.1005 - val_loss: 1.6326 - val_tp: 615.0000 - val_fp: 140.0000 - val_auc: 0.8831 - val_accuracy: 0.5528 - val_precision: 0.8146 - val_recall: 0.3009
# Epoch 3/50
# 512/512 [==============================] - 135s 264ms/step - loss: 2.5354 - tp: 1308.0000 - fp: 1024.0000 - auc: 0.8977 - accuracy: 0.3278 - precision: 0.5609 - recall: 0.1599 - val_loss: 1.4775 - val_tp: 721.0000 - val_fp: 162.0000 - val_auc: 0.9078 - val_accuracy: 0.6047 - val_precision: 0.8165 - val_recall: 0.3527
# Epoch 4/50
# 512/512 [==============================] - 134s 262ms/step - loss: 2.3848 - tp: 1546.0000 - fp: 1090.0000 - auc: 0.9147 - accuracy: 0.3670 - precision: 0.5865 - recall: 0.1890 - val_loss: 1.3723 - val_tp: 823.0000 - val_fp: 182.0000 - val_auc: 0.9202 - val_accuracy: 0.6047 - val_precision: 0.8189 - val_recall: 0.4026
# Epoch 5/50
# 512/512 [==============================] - 133s 260ms/step - loss: 2.2893 - tp: 1715.0000 - fp: 1126.0000 - auc: 0.9247 - accuracy: 0.3756 - precision: 0.6037 - recall: 0.2097 - val_loss: 1.3708 - val_tp: 821.0000 - val_fp: 213.0000 - val_auc: 0.9282 - val_accuracy: 0.6140 - val_precision: 0.7940 - val_recall: 0.4017
# Epoch 6/50
# 512/512 [==============================] - 134s 262ms/step - loss: 2.2042 - tp: 1906.0000 - fp: 1179.0000 - auc: 0.9309 - accuracy: 0.3995 - precision: 0.6178 - recall: 0.2331 - val_loss: 1.2988 - val_tp: 880.0000 - val_fp: 190.0000 - val_auc: 0.9333 - val_accuracy: 0.6389 - val_precision: 0.8224 - val_recall: 0.4305
# Epoch 7/50
# 512/512 [==============================] - 134s 262ms/step - loss: 2.1747 - tp: 1962.0000 - fp: 1082.0000 - auc: 0.9354 - accuracy: 0.4102 - precision: 0.6445 - recall: 0.2399 - val_loss: 1.2962 - val_tp: 927.0000 - val_fp: 216.0000 - val_auc: 0.9372 - val_accuracy: 0.6213 - val_precision: 0.8110 - val_recall: 0.4535
# Epoch 8/50
# 512/512 [==============================] - 135s 263ms/step - loss: 2.1173 - tp: 2056.0000 - fp: 1131.0000 - auc: 0.9388 - accuracy: 0.4217 - precision: 0.6451 - recall: 0.2514 - val_loss: 1.2503 - val_tp: 892.0000 - val_fp: 229.0000 - val_auc: 0.9402 - val_accuracy: 0.6296 - val_precision: 0.7957 - val_recall: 0.4364
# Epoch 9/50
# 512/512 [==============================] - 134s 262ms/step - loss: 2.0573 - tp: 2253.0000 - fp: 1200.0000 - auc: 0.9416 - accuracy: 0.4373 - precision: 0.6525 - recall: 0.2755 - val_loss: 1.2361 - val_tp: 925.0000 - val_fp: 196.0000 - val_auc: 0.9428 - val_accuracy: 0.6394 - val_precision: 0.8252 - val_recall: 0.4525
# Epoch 10/50
# 512/512 [==============================] - 134s 262ms/step - loss: 2.0078 - tp: 2274.0000 - fp: 1237.0000 - auc: 0.9441 - accuracy: 0.4381 - precision: 0.6477 - recall: 0.2781 - val_loss: 1.2492 - val_tp: 921.0000 - val_fp: 229.0000 - val_auc: 0.9451 - val_accuracy: 0.6336 - val_precision: 0.8009 - val_recall: 0.4506
# Epoch 11/50
# 512/512 [==============================] - 133s 260ms/step - loss: 2.0438 - tp: 2275.0000 - fp: 1183.0000 - auc: 0.9459 - accuracy: 0.4424 - precision: 0.6579 - recall: 0.2782 - val_loss: 1.2415 - val_tp: 939.0000 - val_fp: 219.0000 - val_auc: 0.9467 - val_accuracy: 0.6507 - val_precision: 0.8109 - val_recall: 0.4594
# Epoch 12/50
# 512/512 [==============================] - 133s 261ms/step - loss: 1.9854 - tp: 2381.0000 - fp: 1212.0000 - auc: 0.9475 - accuracy: 0.4549 - precision: 0.6627 - recall: 0.2911 - val_loss: 1.2611 - val_tp: 945.0000 - val_fp: 227.0000 - val_auc: 0.9481 - val_accuracy: 0.6443 - val_precision: 0.8063 - val_recall: 0.4623
# Epoch 13/50
# 512/512 [==============================] - 133s 259ms/step - loss: 1.9832 - tp: 2419.0000 - fp: 1244.0000 - auc: 0.9487 - accuracy: 0.4566 - precision: 0.6604 - recall: 0.2958 - val_loss: 1.2447 - val_tp: 947.0000 - val_fp: 206.0000 - val_auc: 0.9492 - val_accuracy: 0.6380 - val_precision: 0.8213 - val_recall: 0.4633
# Epoch 14/50
# 512/512 [==============================] - 135s 264ms/step - loss: 1.9623 - tp: 2442.0000 - fp: 1220.0000 - auc: 0.9497 - accuracy: 0.4579 - precision: 0.6668 - recall: 0.2986 - val_loss: 1.2309 - val_tp: 952.0000 - val_fp: 213.0000 - val_auc: 0.9502 - val_accuracy: 0.6482 - val_precision: 0.8172 - val_recall: 0.4658
# Epoch 15/50
# 512/512 [==============================] - 135s 264ms/step - loss: 1.9531 - tp: 2462.0000 - fp: 1248.0000 - auc: 0.9507 - accuracy: 0.4628 - precision: 0.6636 - recall: 0.3011 - val_loss: 1.2132 - val_tp: 959.0000 - val_fp: 215.0000 - val_auc: 0.9511 - val_accuracy: 0.6502 - val_precision: 0.8169 - val_recall: 0.4692
# Epoch 16/50
# 512/512 [==============================] - 135s 263ms/step - loss: 1.9102 - tp: 2586.0000 - fp: 1219.0000 - auc: 0.9515 - accuracy: 0.4784 - precision: 0.6796 - recall: 0.3162 - val_loss: 1.2223 - val_tp: 958.0000 - val_fp: 243.0000 - val_auc: 0.9520 - val_accuracy: 0.6507 - val_precision: 0.7977 - val_recall: 0.4687
# Epoch 17/50
# 512/512 [==============================] - 134s 262ms/step - loss: 1.9144 - tp: 2544.0000 - fp: 1274.0000 - auc: 0.9524 - accuracy: 0.4605 - precision: 0.6663 - recall: 0.3111 - val_loss: 1.2170 - val_tp: 972.0000 - val_fp: 202.0000 - val_auc: 0.9528 - val_accuracy: 0.6453 - val_precision: 0.8279 - val_recall: 0.4755
# Epoch 18/50
# 512/512 [==============================] - 135s 263ms/step - loss: 1.9131 - tp: 2647.0000 - fp: 1312.0000 - auc: 0.9532 - accuracy: 0.4719 - precision: 0.6686 - recall: 0.3237 - val_loss: 1.1969 - val_tp: 1004.0000 - val_fp: 210.0000 - val_auc: 0.9535 - val_accuracy: 0.6570 - val_precision: 0.8270 - val_recall: 0.4912
# Epoch 19/50
# 512/512 [==============================] - 133s 260ms/step - loss: 1.8811 - tp: 2608.0000 - fp: 1287.0000 - auc: 0.9539 - accuracy: 0.4735 - precision: 0.6696 - recall: 0.3189 - val_loss: 1.2187 - val_tp: 991.0000 - val_fp: 223.0000 - val_auc: 0.9542 - val_accuracy: 0.6517 - val_precision: 0.8163 - val_recall: 0.4848
# Epoch 20/50
# 512/512 [==============================] - 132s 258ms/step - loss: 1.8929 - tp: 2673.0000 - fp: 1248.0000 - auc: 0.9544 - accuracy: 0.4781 - precision: 0.6817 - recall: 0.3269 - val_loss: 1.2166 - val_tp: 973.0000 - val_fp: 206.0000 - val_auc: 0.9547 - val_accuracy: 0.6585 - val_precision: 0.8253 - val_recall: 0.4760
# Epoch 21/50
# 512/512 [==============================] - 135s 264ms/step - loss: 1.9008 - tp: 2638.0000 - fp: 1273.0000 - auc: 0.9549 - accuracy: 0.4765 - precision: 0.6745 - recall: 0.3226 - val_loss: 1.1949 - val_tp: 1005.0000 - val_fp: 220.0000 - val_auc: 0.9552 - val_accuracy: 0.6585 - val_precision: 0.8204 - val_recall: 0.4917
# Epoch 22/50
# 512/512 [==============================] - 133s 260ms/step - loss: 1.8683 - tp: 2716.0000 - fp: 1312.0000 - auc: 0.9555 - accuracy: 0.4812 - precision: 0.6743 - recall: 0.3321 - val_loss: 1.2087 - val_tp: 997.0000 - val_fp: 234.0000 - val_auc: 0.9557 - val_accuracy: 0.6502 - val_precision: 0.8099 - val_recall: 0.4878
# Epoch 23/50
# 512/512 [==============================] - 133s 259ms/step - loss: 1.8689 - tp: 2728.0000 - fp: 1294.0000 - auc: 0.9559 - accuracy: 0.4842 - precision: 0.6783 - recall: 0.3336 - val_loss: 1.1967 - val_tp: 982.0000 - val_fp: 190.0000 - val_auc: 0.9561 - val_accuracy: 0.6654 - val_precision: 0.8379 - val_recall: 0.4804
# Epoch 24/50
# 512/512 [==============================] - 132s 258ms/step - loss: 1.8612 - tp: 2765.0000 - fp: 1258.0000 - auc: 0.9563 - accuracy: 0.4910 - precision: 0.6873 - recall: 0.3381 - val_loss: 1.1935 - val_tp: 983.0000 - val_fp: 197.0000 - val_auc: 0.9565 - val_accuracy: 0.6644 - val_precision: 0.8331 - val_recall: 0.4809
# Epoch 25/50
# 512/512 [==============================] - 132s 258ms/step - loss: 1.8507 - tp: 2782.0000 - fp: 1280.0000 - auc: 0.9567 - accuracy: 0.4892 - precision: 0.6849 - recall: 0.3402 - val_loss: 1.1924 - val_tp: 980.0000 - val_fp: 204.0000 - val_auc: 0.9569 - val_accuracy: 0.6624 - val_precision: 0.8277 - val_recall: 0.4795
# Epoch 26/50
# 512/512 [==============================] - 132s 258ms/step - loss: 1.8287 - tp: 2847.0000 - fp: 1302.0000 - auc: 0.9570 - accuracy: 0.4924 - precision: 0.6862 - recall: 0.3481 - val_loss: 1.1789 - val_tp: 999.0000 - val_fp: 199.0000 - val_auc: 0.9572 - val_accuracy: 0.6678 - val_precision: 0.8339 - val_recall: 0.4887
# Epoch 27/50
# 512/512 [==============================] - 132s 258ms/step - loss: 1.8314 - tp: 2803.0000 - fp: 1252.0000 - auc: 0.9574 - accuracy: 0.4907 - precision: 0.6912 - recall: 0.3427 - val_loss: 1.1562 - val_tp: 1025.0000 - val_fp: 208.0000 - val_auc: 0.9576 - val_accuracy: 0.6800 - val_precision: 0.8313 - val_recall: 0.5015
# Epoch 28/50
# 512/512 [==============================] - 133s 260ms/step - loss: 1.7941 - tp: 2912.0000 - fp: 1263.0000 - auc: 0.9578 - accuracy: 0.5007 - precision: 0.6975 - recall: 0.3561 - val_loss: 1.1919 - val_tp: 1014.0000 - val_fp: 214.0000 - val_auc: 0.9580 - val_accuracy: 0.6619 - val_precision: 0.8257 - val_recall: 0.4961
# Epoch 29/50
# 512/512 [==============================] - 131s 256ms/step - loss: 1.8124 - tp: 2911.0000 - fp: 1249.0000 - auc: 0.9581 - accuracy: 0.4983 - precision: 0.6998 - recall: 0.3560 - val_loss: 1.1734 - val_tp: 1027.0000 - val_fp: 212.0000 - val_auc: 0.9583 - val_accuracy: 0.6624 - val_precision: 0.8289 - val_recall: 0.5024
# Epoch 30/50
# 512/512 [==============================] - 132s 257ms/step - loss: 1.8260 - tp: 2879.0000 - fp: 1311.0000 - auc: 0.9584 - accuracy: 0.5020 - precision: 0.6871 - recall: 0.3520 - val_loss: 1.1968 - val_tp: 998.0000 - val_fp: 223.0000 - val_auc: 0.9585 - val_accuracy: 0.6487 - val_precision: 0.8174 - val_recall: 0.4883
# Epoch 31/50
# 512/512 [==============================] - 132s 257ms/step - loss: 1.8012 - tp: 2899.0000 - fp: 1274.0000 - auc: 0.9587 - accuracy: 0.5004 - precision: 0.6947 - recall: 0.3545 - val_loss: 1.1836 - val_tp: 1022.0000 - val_fp: 218.0000 - val_auc: 0.9588 - val_accuracy: 0.6737 - val_precision: 0.8242 - val_recall: 0.5000
# Epoch 32/50
# 512/512 [==============================] - 131s 256ms/step - loss: 1.7802 - tp: 2968.0000 - fp: 1234.0000 - auc: 0.9589 - accuracy: 0.5044 - precision: 0.7063 - recall: 0.3629 - val_loss: 1.1992 - val_tp: 1008.0000 - val_fp: 232.0000 - val_auc: 0.9590 - val_accuracy: 0.6512 - val_precision: 0.8129 - val_recall: 0.4932

# %%
model.save('/content/drive/MyDrive/VGG16-Epoch50DataAugmentationHighROCVersion3.h5')

# %%
plt.figure()
plt.plot(history_vgg .history['val_loss'], label = 'Val loss')
plt.plot(history_vgg .history['loss'], label = 'Train loss')
plt.legend()
plt.show()
plt.figure()
plt.plot(history_vgg .history['val_accuracy'], label = 'Val accuracy')
plt.plot(history_vgg .history['accuracy'], label = 'Accuracy')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(history_vgg .history['val_auc'], label = 'val_auc')
plt.plot(history_vgg .history['auc'], label = 'Train auc')
plt.legend()
plt.show()

plt.figure()
plt.plot(history_vgg .history['val_tp'], label = 'Val TP')
plt.plot(history_vgg .history['tp'], label = 'Train TP')
plt.plot(history_vgg .history['val_fp'], label = 'Val FP')
plt.plot(history_vgg .history['fp'], label = 'Train FP')
plt.legend()
plt.show()

plt.figure()
plt.plot(history_vgg .history['val_precision'], label = 'Val Precision')
plt.plot(history_vgg .history['precision'], label = 'Train Precision')
plt.legend()
plt.show()

plt.figure()
plt.plot(history_vgg .history['val_recall'], label = 'Val Recall')
plt.plot(history_vgg .history['recall'], label = 'Train Recall')
plt.legend()
plt.show()
