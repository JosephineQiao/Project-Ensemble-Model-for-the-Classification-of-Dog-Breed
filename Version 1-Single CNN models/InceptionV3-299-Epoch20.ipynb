# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
import pandas as pd
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras import applications
from keras.layers import Activation, Dropout, Flatten, Dense,GlobalAveragePooling2D, BatchNormalization
import visualkeras

# %%
labels_csv = pd.read_csv('E:\\dx\\Level 6\\Project\\Topic-Ensemble Model for the Classification of Dog Breed\\\Codes\\Dog-Breed-Classification-using-Ensemble-Pretrained-Models-main\\labels.csv')
labels_csv['id'] = [str(fname) + '.jpg' for fname in labels_csv['id']]
data_train = pathlib.Path('E:\\dx\\Level 6\\Project\\Topic-Ensemble Model for the Classification of Dog Breed\\Dataset\\120dog breeds-299\\train')
data_test = pathlib.Path('E:\\dx\\Level 6\\Project\\Topic-Ensemble Model for the Classification of Dog Breed\\Dataset\\120dog breeds-299\\train')

# %%
batch_size = 16
img_size = 299

# %%
datagen = ImageDataGenerator(preprocessing_function = keras.applications.inception_v3.preprocess_input, validation_split=0.2)
train_generator = datagen.flow_from_dataframe(
                        dataframe = labels_csv,
                        directory = data_train,
                        subset='training',
                        x_col='id',
                        y_col='breed',
                        batch_size=batch_size,
                        shuffle=True,
                        class_mode='sparse',
                        color_mode='rgb',
                        target_size=(img_size, img_size))

validation_generator = datagen.flow_from_dataframe(
                        dataframe = labels_csv,
                        directory = data_train,
                        subset='validation',
                        x_col='id',
                        y_col='breed',
                        batch_size=batch_size,
                        shuffle=True,
                        class_mode='sparse',
                        color_mode='rgb',
                        target_size=(img_size, img_size))
# Out:
# Found 8178 validated image filenames belonging to 120 classes.
# Found 2044 validated image filenames belonging to 120 classes.

# %%
base = applications.inception_v3.InceptionV3(include_top=False, weights='imagenet',input_shape=(224,224,3))

for layer in base.layers:
    layer.trainable=False

model = Sequential()
model.add(base)
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.5))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(120, activation='softmax'))
model.summary()

optimizer=tf.keras.optimizers.Adam(learning_rate = 0.0001)
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  batch_normalization_94 (Bat  (None, 5, 5, 2048)       8192
#  chNormalization)
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 120)               123000
#
# =================================================================
# Total params: 24,032,152
# Trainable params: 2,225,272
# Non-trainable params: 21,806,880
# _________________________________________________________________

# %%
history_inc = model.fit(train_generator, epochs=20, verbose = 1,
                        validation_data=validation_generator)
# Out:
# Epoch 1/20
# 512/512 [==============================] - 424s 811ms/step - loss: 2.7263 - accuracy: 0.4627 - val_loss: 0.7094 - val_accuracy: 0.8645
# Epoch 2/20
# 512/512 [==============================] - 414s 809ms/step - loss: 0.8049 - accuracy: 0.8178 - val_loss: 0.4035 - val_accuracy: 0.8841
# Epoch 3/20
# 512/512 [==============================] - 415s 811ms/step - loss: 0.5407 - accuracy: 0.8525 - val_loss: 0.3564 - val_accuracy: 0.8845
# Epoch 4/20
# 512/512 [==============================] - 414s 809ms/step - loss: 0.4268 - accuracy: 0.8730 - val_loss: 0.3479 - val_accuracy: 0.8899
# Epoch 5/20
# 512/512 [==============================] - 418s 817ms/step - loss: 0.3778 - accuracy: 0.8838 - val_loss: 0.3382 - val_accuracy: 0.8909
# Epoch 6/20
# 512/512 [==============================] - 417s 814ms/step - loss: 0.3366 - accuracy: 0.8956 - val_loss: 0.3445 - val_accuracy: 0.8836
# Epoch 7/20
# 512/512 [==============================] - 414s 808ms/step - loss: 0.3031 - accuracy: 0.9040 - val_loss: 0.3437 - val_accuracy: 0.8860
# Epoch 8/20
# 512/512 [==============================] - 414s 808ms/step - loss: 0.2790 - accuracy: 0.9083 - val_loss: 0.3443 - val_accuracy: 0.8904
# Epoch 9/20
# 512/512 [==============================] - 439s 858ms/step - loss: 0.2546 - accuracy: 0.9146 - val_loss: 0.3515 - val_accuracy: 0.8933
# Epoch 10/20
# 512/512 [==============================] - 507s 990ms/step - loss: 0.2307 - accuracy: 0.9246 - val_loss: 0.3457 - val_accuracy: 0.8973
# Epoch 11/20
# 512/512 [==============================] - 486s 949ms/step - loss: 0.2177 - accuracy: 0.9283 - val_loss: 0.3467 - val_accuracy: 0.8933
# Epoch 12/20
# 512/512 [==============================] - 457s 892ms/step - loss: 0.2006 - accuracy: 0.9324 - val_loss: 0.3573 - val_accuracy: 0.8924
# Epoch 13/20
# 512/512 [==============================] - 445s 868ms/step - loss: 0.1957 - accuracy: 0.9308 - val_loss: 0.3703 - val_accuracy: 0.8909
# Epoch 14/20
# 512/512 [==============================] - 437s 854ms/step - loss: 0.1789 - accuracy: 0.9418 - val_loss: 0.3675 - val_accuracy: 0.8904
# Epoch 15/20
# 512/512 [==============================] - 448s 874ms/step - loss: 0.1637 - accuracy: 0.9447 - val_loss: 0.3656 - val_accuracy: 0.9007
# Epoch 16/20
# 512/512 [==============================] - 448s 875ms/step - loss: 0.1642 - accuracy: 0.9469 - val_loss: 0.3750 - val_accuracy: 0.8929
# Epoch 17/20
# 512/512 [==============================] - 451s 881ms/step - loss: 0.1574 - accuracy: 0.9468 - val_loss: 0.3764 - val_accuracy: 0.8880
# Epoch 18/20
# 512/512 [==============================] - 449s 877ms/step - loss: 0.1412 - accuracy: 0.9527 - val_loss: 0.3807 - val_accuracy: 0.8953
# Epoch 19/20
# 512/512 [==============================] - 452s 882ms/step - loss: 0.1365 - accuracy: 0.9516 - val_loss: 0.3783 - val_accuracy: 0.8948
# Epoch 20/20
# 512/512 [==============================] - 458s 895ms/step - loss: 0.1234 - accuracy: 0.9585 - val_loss: 0.3888 - val_accuracy: 0.8889

# %%
plt.figure()
plt.plot(history_inc .history['val_loss'], label = 'Val loss')
plt.plot(history_inc .history['loss'], label = 'Train loss')
plt.legend()
plt.show()
plt.figure()
plt.plot(history_inc .history['val_accuracy'], label = 'Val accuracy')
plt.plot(history_inc .history['accuracy'], label = 'Accuracy')
plt.legend()
plt.show()

# %%
visualkeras.layered_view(model,  legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=1131x63>
