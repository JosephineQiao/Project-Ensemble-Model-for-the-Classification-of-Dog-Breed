# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import pandas as pd
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import visualkeras as visualkeras
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras import applications
from keras.layers import Activation, Dropout, Flatten, Dense, GlobalAveragePooling2D, BatchNormalization
from keras.callbacks import ModelCheckpoint
import visualkeras

# %%
labels_csv = pd.read_csv('E:\\dx\\Level 6\\Project\\Topic-Ensemble Model for the Classification of Dog Breed\\\Codes\\Dog-Breed-Classification-using-Ensemble-Pretrained-Models-main\\labels.csv')
labels_csv['id'] = [str(fname) + '.jpg' for fname in labels_csv['id']]
data_train = pathlib.Path('E:\\dx\\Level 6\\Project\\Topic-Ensemble Model for the Classification of Dog Breed\\Dataset\\120dog breeds-224\\train')
data_test = pathlib.Path('E:\\dx\\Level 6\\Project\\Topic-Ensemble Model for the Classification of Dog Breed\\Dataset\\120dog breeds-224\\train')

# %%
batch_size = 16
img_size = 224

# %%
datagen = ImageDataGenerator(preprocessing_function = keras.applications.vgg16.preprocess_input, validation_split=0.2)

train_generator = datagen.flow_from_dataframe(
                        dataframe = labels_csv,
                        directory = data_train,
                        subset="training",
                        x_col="id",
                        y_col="breed",
                        batch_size=batch_size,
                        shuffle=True,
                        class_mode="sparse",
                        color_mode="rgb",
                        target_size=(img_size, img_size))

validation_generator = datagen.flow_from_dataframe(
                        dataframe = labels_csv,
                        directory = data_train,
                        subset="validation",
                        x_col="id",
                        y_col="breed",
                        batch_size=batch_size,
                        shuffle=True,
                        class_mode="sparse",
                        color_mode="rgb",
                        target_size=(img_size, img_size))
# Out:
# Found 8178 validated image filenames belonging to 120 classes.
# Found 2044 validated image filenames belonging to 120 classes.

# %%
vgg16 = applications.vgg16.VGG16(include_top=False, weights='imagenet',input_shape=(224,224,3))

for layer in vgg16.layers:
    layer.trainable=False

model = Sequential()
model.add(vgg16)
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.5))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(120, activation='softmax'))
model.summary()

optimizer=tf.keras.optimizers.Adam(learning_rate = 0.001)
# optimizer = tf.keras.optimizers.RMSprop(learning_rate=1e-4, rho=0.9)
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  batch_normalization (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 256)               262400
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 120)               30840
#
# =================================================================
# Total params: 15,535,288
# Trainable params: 819,576
# Non-trainable params: 14,715,712
# _________________________________________________________________

# %%
history_vgg = model.fit(train_generator, epochs=20, verbose = 1,
                        validation_data=validation_generator)
# Out:
# Epoch 1/20
# 512/512 [==============================] - 893s 2s/step - loss: 3.9964 - accuracy: 0.1115 - val_loss: 2.2857 - val_accuracy: 0.4481
# Epoch 2/20
# 512/512 [==============================] - 885s 2s/step - loss: 2.7538 - accuracy: 0.2786 - val_loss: 1.6775 - val_accuracy: 0.5553
# Epoch 3/20
# 512/512 [==============================] - 900s 2s/step - loss: 2.4217 - accuracy: 0.3481 - val_loss: 1.5076 - val_accuracy: 0.5886
# Epoch 4/20
# 512/512 [==============================] - 955s 2s/step - loss: 2.2457 - accuracy: 0.3914 - val_loss: 1.4269 - val_accuracy: 0.6164
# Epoch 5/20
# 512/512 [==============================] - 976s 2s/step - loss: 2.1744 - accuracy: 0.4090 - val_loss: 1.3840 - val_accuracy: 0.6233
# Epoch 6/20
# 512/512 [==============================] - 998s 2s/step - loss: 2.0804 - accuracy: 0.4313 - val_loss: 1.2916 - val_accuracy: 0.6429
# Epoch 7/20
# 512/512 [==============================] - 987s 2s/step - loss: 2.0128 - accuracy: 0.4442 - val_loss: 1.3103 - val_accuracy: 0.6375
# Epoch 8/20
# 512/512 [==============================] - 1023s 2s/step - loss: 1.9296 - accuracy: 0.4730 - val_loss: 1.2691 - val_accuracy: 0.6458
# Epoch 9/20
# 512/512 [==============================] - 1005s 2s/step - loss: 1.9371 - accuracy: 0.4598 - val_loss: 1.2561 - val_accuracy: 0.6453
# Epoch 10/20
# 512/512 [==============================] - 1013s 2s/step - loss: 1.8765 - accuracy: 0.4831 - val_loss: 1.2625 - val_accuracy: 0.6541
# Epoch 11/20
# 512/512 [==============================] - 955s 2s/step - loss: 1.8472 - accuracy: 0.4787 - val_loss: 1.2796 - val_accuracy: 0.6443
# Epoch 12/20
# 512/512 [==============================] - 946s 2s/step - loss: 1.8401 - accuracy: 0.4840 - val_loss: 1.2474 - val_accuracy: 0.6404
# Epoch 13/20
# 512/512 [==============================] - 970s 2s/step - loss: 1.7913 - accuracy: 0.4971 - val_loss: 1.2277 - val_accuracy: 0.6556
# Epoch 14/20
# 512/512 [==============================] - 1055s 2s/step - loss: 1.7797 - accuracy: 0.5028 - val_loss: 1.2215 - val_accuracy: 0.6448
# Epoch 15/20
# 512/512 [==============================] - 1062s 2s/step - loss: 1.7689 - accuracy: 0.5064 - val_loss: 1.2120 - val_accuracy: 0.6624
# Epoch 16/20
# 512/512 [==============================] - 1008s 2s/step - loss: 1.7551 - accuracy: 0.5084 - val_loss: 1.2090 - val_accuracy: 0.6634
# Epoch 17/20
# 512/512 [==============================] - 997s 2s/step - loss: 1.7570 - accuracy: 0.5135 - val_loss: 1.2211 - val_accuracy: 0.6566
# Epoch 18/20
# 512/512 [==============================] - 1034s 2s/step - loss: 1.7334 - accuracy: 0.5132 - val_loss: 1.1983 - val_accuracy: 0.6712
# Epoch 19/20
# 512/512 [==============================] - 966s 2s/step - loss: 1.7206 - accuracy: 0.5188 - val_loss: 1.1985 - val_accuracy: 0.6649
# Epoch 20/20
# 512/512 [==============================] - 964s 2s/step - loss: 1.7018 - accuracy: 0.5164 - val_loss: 1.2282 - val_accuracy: 0.6595

# %%
plt.figure()
plt.plot(history_vgg .history['val_loss'], label = 'Val loss')
plt.plot(history_vgg .history['loss'], label = 'Train loss')
plt.legend()
plt.show()
plt.figure()
plt.plot(history_vgg .history['val_accuracy'], label = 'Val accuracy')
plt.plot(history_vgg .history['accuracy'], label = 'Accuracy')
plt.legend()
plt.show()

# %%
visualkeras.layered_view(model,  legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=589x74>
